# %% [markdown]
# # TwitterAPI
#
# This API will be able to return tweets within a given radius of a latitude/longitude

# %%
#!pip install TwitterAPI
# Out:
# Collecting TwitterAPI
#   Downloading https://files.pythonhosted.org/packages/9a/08/ca64f836886f6e29c1450a3ab9e81c3f3bba6398bd00b8340cec13334014/TwitterAPI-2.5.9.tar.gz
# Requirement already satisfied: requests in /anaconda3/lib/python3.6/site-packages (from TwitterAPI) (2.21.0)
# Collecting requests_oauthlib (from TwitterAPI)
#   Downloading https://files.pythonhosted.org/packages/c2/e2/9fd03d55ffb70fe51f587f20bcf407a6927eb121de86928b34d162f0b1ac/requests_oauthlib-1.2.0-py2.py3-none-any.whl
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests->TwitterAPI) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests->TwitterAPI) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests->TwitterAPI) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests->TwitterAPI) (3.0.4)
# Collecting oauthlib>=3.0.0 (from requests_oauthlib->TwitterAPI)
#   Downloading https://files.pythonhosted.org/packages/16/95/699466b05b72b94a41f662dc9edf87fda4289e3602ecd42d27fcaddf7b56/oauthlib-3.0.1-py2.py3-none-any.whl (142kB)
#     100% |████████████████████████████████| 143kB 6.8MB/s ta 0:00:01
# Building wheels for collected packages: TwitterAPI
#   Building wheel for TwitterAPI (setup.py) ... done
#   Stored in directory: /Users/awharmon/Library/Caches/pip/wheels/1f/f9/82/8b46b92e9860fccb75ca97af2fa0bd80a88e02a2001a975537
# Successfully built TwitterAPI
# Installing collected packages: oauthlib, requests-oauthlib, TwitterAPI
# Successfully installed TwitterAPI-2.5.9 oauthlib-3.0.1 requests-oauthlib-1.2.0

# %%
from TwitterAPI import TwitterAPI
import json

import pandas as pd
import time

# %% [markdown]
# ### Waiting on credential confirmation

# %%
api = TwitterAPI(consumer_key='Nu3roM7Nb9pMxyp1gfQ9DAP8Z',
                 consumer_secret='5fiwdiStdG8rSXCTI6aGUQIbDRkm2ioaDxZGQtPJUuZYO6voqE',
                 access_token_key='325714999-uGibrBLDPcbOPlUU0kky5A7q8JVyZBNFuNIi1sem',
                 access_token_secret='v4evcFULPgfqCRX0DMd9ZBwimIf8pHkHnyJhDGQObsAe8')

# %%
sandbox = 'fullarchive'
label = 'awharmonfulltest' # Specific to application and set in dev environment

# %%
list_tweets = []
#next=None

# %%
web_request_count = 3
web_request_count
# Out:
# 3

# %%
r = api.request('search/tweets', {'q':'pizza'})
for item in r:
        print(item)
# Out:
# {'created_at': 'Mon Apr 22 20:36:53 +0000 2019', 'id': 1120426266409222144, 'id_str': '1120426266409222144', 'text': 'i hate fish \U0001f92e but i do love pineapples\U0001f92a\U0001f92a🍄 — HSJSHSHS pineapple is with pizza already tho 😔 https://t.co/Om8MXF1Dw2', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/Om8MXF1Dw2', 'expanded_url': 'https://curiouscat.me/bIackpinkaus/post/855949819?t=1555965412', 'display_url': 'curiouscat.me/bIackpinkaus/p…', 'indices': [91, 114]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href
 'indices': [0, 23]}]}, 'description': {'urls': [{'url': 'https://t.co/oDi6sD5JSA', 'expanded_url': 'http://NewPaltz.com', 'display_url': 'NewPaltz.com', 'indices': [136, 159]}]}}, 'protected': False, 'followers_count': 18, 'friends_count': 53, 'listed_count': 0, 'created_at': 'Tue Jun 12 05:13:05 +0000 2018', 'favourites_count': 13, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 55, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1006432830824636416/Z0-0EnQ0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1006432830824636416/Z0-0EnQ0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1006403994770649088/1529535530', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}
# {'created_at': 'Mon Apr 22 20:36:52 +0000 2019', 'id': 1120426263724920834, 'id_str': '1120426263724920834', 'text': '@kebaniko Pismam hek lî mal ne bûn jî we yeke min pizza cekir', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kebaniko', 'name': 'Li Aşxanê Aşpêj', 'id': 1077893477986455552, 'id_str': '1077893477986455552', 'indices': [0, 9]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'tr'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1120383880715034625, 'in_reply_to_status_id_str': '1120383880715034625', 'in_reply_to_user_id': 1077893477986455552, 'in_reply_to_user_id_str': '1077893477986455552', 'in_reply_to_screen_name': 'kebaniko', 'user': {'id': 2912541418, 'id_str': '2912541418', 'name': 'Axayê Kercewsê', 'screen_name': 'axayekercewse', 'location': '', 'description': 'Toristan', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1825, 'friends_count': 2148, 'listed_count': 0, 'created_at': 'Tue Dec 09 10:29:35 +0000 2014', 'favourites_count': 20694, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1253, 'lang': 'tr', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/964190458988593152/_HHHatFJ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964190458988593152/_HHHatFJ_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'tr'}
# {'created_at': 'Mon Apr 22 20:36:51 +0000 2019', 'id': 1120426261036326915, 'id_str': '1120426261036326915', 'text': 'RT @aokis_pizza: ⭐️＼ハンバーグ師匠の\n\u3000あの巨大ナイフ&amp;フォークが\u3000\u3000\u3000\n\u3000\u3000フォロー&amp;リツイートで\n\u3000\u3000\u3000\u3000\u3000\u3000当たる！！／⭐️\n\n①@aokis_pizzaをフォロー\n②このツイートをリツイート\n③応募完了！\n\n\xa0※ベルトは含みません&lt;(_ _)&gt;\nht…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'aokis_pizza', 'name': 'アオキーズ・ピザ【公式】', 'id': 155191793, 'id_str': '155191793', 'indices': [3, 15]}, {'screen_name': 'aokis_pizza', 'name': 'アオキーズ・ピザ【公式】', 'id': 155191793, 'id_str': '155191793', 'indices': [86, 98]}], 'urls': []}, 'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2574302036, 'id_str': '2574302036', 'name': 'こえみん', 'screen_name': 'koemitorasi', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 190, 'friends_count': 2330, 'listed_count': 4, 'created_at': 'Wed Jun 18 06:49:54 +0000 2014', 'favourites_count': 41, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 37936, 'lang': 'ja', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/588041861371133952/CQUWS7-0_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/588041861371133952/CQUWS7-0_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2574302036/1443159053', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Feb 14 07:28:44 +0000 2019', 'id': 1095947936251277312, 'id_str': '1095947936251277312', 'text': '⭐️＼ハンバーグ師匠の\n\u3000あの巨大ナイフ&amp;フォークが\u3000\u3000\u3000\n\u3000\u3000フォロー&amp;リツイートで\n\u3000\u3000\u3000\u3000\u3000\u3000当たる！！／⭐️\n\n①@aokis_pizzaをフォロー\n②このツイートをリツイート\n③応募完了！\n\n\xa0※ベルトは含みません&lt;(_… https://t.co/eg6SOjjUwB', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 
 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'chaoticsouI', 'name': 'Alekai Nässer.', 'id': 2492420225, 'id_str': '2492420225', 'indices': [0, 12]}], 'urls': [{'url': 'https://t.co/FaR0lSrQQR', 'expanded_url': 'https://twitter.com/i/web/status/1120426259484413953', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [119, 142]}]}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="https://twittrp.com" rel="nofollow">Twitt-RP</a>', 'in_reply_to_status_id': 1120426252211560449, 'in_reply_to_status_id_str': '1120426252211560449', 'in_reply_to_user_id': 2870658010, 'in_reply_to_user_id_str': '2870658010', 'in_reply_to_screen_name': 'fxckingcop', 'user': {'id': 2870658010, 'id_str': '2870658010', 'name': 'ᴀʟᴀɴ — fc!au', 'screen_name': 'fxckingcop', 'location': 'Piso 1A.', 'description': "39. ∫︰❪ 𝙥𝙤𝙡𝙞𝙘𝙚𝙢𝙖𝙣 ▸ #ʀᴀᴅɪᴏsᴜʀᴠɪᴠᴏʀs ❫ ↻ sᴍᴏᴋᴇʀ  ¦  ❛❛—ᴛʜᴇʀᴇ's ɴᴏ 𝖋𝖊𝖆𝖗 𝖔𝖗 𝖗𝖊𝖌𝖗𝖊𝖙 ʙᴜᴛ ɴᴏ 𝖘𝖊𝖓𝖘𝖊 𝖔𝖋 𝖙𝖗𝖎𝖚𝖒𝖕𝖍 ᴇɪᴛʜᴇʀ. ɪᴛ's ᴊᴜsᴛ ᴀ ᴊᴏʙ ᴛʜᴀᴛ ʜᴀᴅ ᴛᴏ ʙᴇ ᴅᴏɴᴇ.❜❜", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 259, 'friends_count': 64, 'listed_count': 10, 'created_at': 'Mon Nov 10 14:26:18 +0000 2014', 'favourites_count': 3178, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2787, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1120075297678872579/ielzopic_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1120075297678872579/ielzopic_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2870658010/1555881857', 'profile_link_color': '9266CC', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'es'}
# {'created_at': 'Mon Apr 22 20:36:49 +0000 2019', 'id': 1120426251972485122, 'id_str': '1120426251972485122', 'text': 'RT @UnMirrreyHabla: Solo necesito una pizza y a mi novia.😍🤤🍕', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'UnMirrreyHabla', 'name': 'L.', 'id': 339148942, 'id_str': '339148942', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1120420539934363653, 'id_str': '1120420539934363653', 'name': 'Ale.xcamp', 'screen_name': 'Alexcam12168198', 'location': '', 'description': 'Modelo |17 años|♥️', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 0, 'friends_count': 56, 'listed_count': 0, 'created_at': 'Mon Apr 22 20:14:07 +0000 2019', 'favourites_count': 0, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 11, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1120420641516158979/OdL7gujz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1120420641516158979/OdL7gujz_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1120420539934363653/1555965158', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Apr 18 03:05:56 +0000 2019', 'id': 1118712237168955400, 'id_str': '1118712237168955400', 'text': 'Solo necesito una pizza y a mi novia.😍🤤🍕', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 339148942, 'id_str': '339148942', 'name': 'L.', 'screen_name': 'UnMirrreyHabla', 'location': 'Toluca, México', 'description': '•Soy como el amor de tu vida, pero bien vestido. Contacto/Negocios unmirrreyhabla@gmail.com✉️ Instagram: https://t.co/pAeR2Hz8eG📷', 'url': 'https://t.co/RZFgY2WOWq', 'entities': {'url': {'urls': [{'url': 'https://t.co/RZFgY2WOW
com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 5653, 'friends_count': 1898, 'listed_count': 86, 'created_at': 'Mon Oct 27 14:06:19 +0000 2014', 'favourites_count': 8343, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 25486, 'lang': 'de', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_ba ...
# {'created_at': 'Mon Apr 22 20:36:47 +0000 2019', 'id': 1120426242078064642, 'id_str': '1120426242078064642', 'text': 'RT @bestinthemed: La Tavola Calda - Divine Tastes from #Naples in #Corfu! #italianrestaurant #restaurant #italian #napoli #corfu #travel #c…', 'truncated': False, 'entities': {'hashtags': [{'text': 'Naples', 'indices': [55, 62]}, {'text': 'Corfu', 'indices': [66, 72]}, {'text': 'italianrestaurant', 'indices': [74, 92]}, {'text': 'restaurant', 'indices': [93, 104]}, {'text': 'italian', 'indices': [105, 113]}, {'text': 'napoli', 'indices': [114, 121]}, {'text': 'corfu', 'indices': [122, 128]}, {'text': 'travel', 'indices': [129, 136]}], 'symbols': [], 'user_mentions': [{'screen_name': 'bestinthemed', 'name': 'In Love with the Med', 'id': 39112591, 'id_str': '39112591', 'indices': [3, 16]}], 'urls': []}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ca'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 26504390, 'id_str': '26504390', 'name': 'Bliss in Reach', 'screen_name': 'blissinreach', 'location': 'London, United Kingdom', 'description': '#Traveling the world exploring #luxuryvillas!!!', 'url': 'https://t.co/3PMf4CaiTp', 'entities': {'url': {'urls': [{'url': 'https://t.co/3PMf4CaiTp', 'expanded_url': 'http://www.blissinreach.com', 'display_url': 'blissinreach.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1702, 'friends_count': 776, 'listed_count': 59, 'created_at': 'Wed Mar 25 14:11:06 +0000 2009', 'favourites_count': 912, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 2018, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/764444416568426496/cJ6EV0Qi_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/764444416568426496/cJ6EV0Qi_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26504390/1530386962', 'profile_link_color': '2873AD', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'F9384C', 'profile_text_color': 'D9297A', 'profile_use_background_image': False, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Apr 22 20:07:59 +0000 2019', 'id': 1120418996585627650, 'id_str': '1120418996585627650', 'text': 'La Tavola Calda - Divine Tastes from #Naples in #Corfu! #italianrestaurant #restaurant #italian #napoli #corfu… https://t.co/4WRh6N2Kpt', 'truncated': True, 'entities': {'hashtags': [{'text': 'Naples', 'indices': [37, 44]}, {'text': 'Corfu', 'indices': [48, 54]}, {'text': 'italianrestaurant', 'indices': [56, 74]}, {'text': 'restaurant', 'indices': [75, 86]}, {'text': 'italian', 'indices': [87, 95]}, {'text': 'napoli', 'indices': [96, 103]}, {'text': 'corfu', 'indices': [104, 110]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/4WRh6N2Kpt', 'expanded_url': 'https://twitter.com/i/web/status/1120418996585627650', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [112, 135]}]}, 'metadata': {'result_type': 'recent', 'iso_language_code': 'ca'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_ ...
# {'created_at': 'Mon Apr 22 20:36:45 +0000 2019', 'id': 1120426233085480962, 'id_str': '1120426233085480962', 'text': 'RT @VanteMilka: Comenten por Tweets separados y con los siguientes Ht y BTS \n\nAsí \n#BBMAsTopSocial BTS @BTS_twt \n\n¿Si te tuvieras que teñir…', 'truncated': False, 'entities': {'hashtags': [{'text': 'BBMAsTopSocial', 'indices': [83, 98]}], 'symbols': [], 'user_mentions': [{'screen_name': 'VanteMilka', 'name': 'Mileee🇦🇷 ᵗʰᵉ\xa0ᵐᵃᵖ\xa0ᵒᶠ\xa0ˢᵒᵘˡ', 'id': 1031535198687649792, 'id_str': '1031535198687649792', 'indices': [3, 14]}, {'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [103, 111]}], 'urls': []}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1044952971648409600, 'id_str': '1044952971648409600', 'name': '💫 Juli 💫', 'screen_name': 'EPinguinos', 'location': 'debajo de tu cama bb', 'description': '👑ARMY👑\n🌸EXO-L🌸\n🌟ATINY🌟\n🌺BLINK🌺\n✨STAY✨', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 111, 'friends_count': 268, 'listed_count': 0, 'created_at': 'Wed Sep 26 14:12:57 +0000 2018', 'favourites_count': 5273, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1300, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1116622700066131968/DcBrsefv_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1116622700066131968/DcBrsefv_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1044952971648409600/1555058572', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Apr 22 16:56:50 +0000 2019', 'id': 1120370890146033666, 'id_str': '1120370890146033666', 'text': 'Comenten por Tweets separados y con los siguientes Ht y BTS \n\nAsí \n#BBMAsTopSocial BTS @BTS_twt \n\n¿Si te tuvieras q… https://t.co/3RxkDLdoK5', 'truncated': True, 'entities': {'hashtags': [{'text': 'BBMAsTopSocial', 'indices': [67, 82]}], 'symbols': [], 'user_mentions': [{'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [87, 95]}], 'urls': [{'url': 'https://t.co/3RxkDLdoK5', 'expanded_url': 'https://twitter.com/i/web/status/1120370890146033666', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'es', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1031535198687649792, 'id_str': '1031535198687649792', 'name': 'Mileee🇦🇷 ᵗʰᵉ\xa0ᵐᵃᵖ\xa0ᵒᶠ\xa0ˢᵒᵘˡ', 'screen_name': 'VanteMilka', 'location': 'Con Tae, Hyun, Beom y  Xion', 'description': "발자국 남기고 떠나가시면 제가 그 온길 지킬게요 #테테\n\n              @BTS_twt        \n-,'~Bᴀɴɢᴛᴀɴ\xa0ᴇs\xa0ᴍɪ\xa0ғᴇʟɪᴄɪᴅᴀᴅ~,'-\n\nʲʲᵏ+ᵏᵗʰ 💌 ᵖʲᵐ+ᵏᵗʰ\xa0💌\n\nCuenta de respaldo @MilteBTS", 'url': None, 'entities': {'description': {'urls': []}}, 'protect ...
# {'created_at': 'Mon Apr 22 20:36:43 +0000 2019', 'id': 1120426226307469318, 'id_str': '1120426226307469318', 'text': '@jikookmodel @BTS_twt Preto bordo e roxo\nAçaí strogonoff e pizza\nMic drop fake love go go apaman not today save me', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'jikookmodel', 'name': 'liα;', 'id': 1061891490400624642, 'id_str': '1061891490400624642', 'indices': [0, 12]}, {'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [13, 21]}], 'urls': []}, 'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1120361763004747777, 'in_reply_to_status_id_str': '1120361763004747777', 'in_reply_to_user_id': 1061891490400624642, 'in_reply_to_user_id_str': '1061891490400624642', 'in_reply_to_screen_name': 'jikookmodel', 'user': {'id': 1120114627860467713, 'id_str': '1120114627860467713', 'name': '@Jú:lia:-) 💕', 'screen_name': 'Jlia90550883', 'location': '', 'description': 'nada a comentar por enquato', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 60, 'friends_count': 405, 'listed_count': 0, 'created_at': 'Sun Apr 21 23:58:32 +0000 2019', 'favourites_count': 4, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 8, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1120114943376994307/Yhjw5Tyb_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1120114943376994307/Yhjw5Tyb_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'pt'}
# {'created_at': 'Mon Apr 22 20:36:40 +0000 2019', 'id': 1120426214454452224, 'id_str': '1120426214454452224', 'text': '.@stoolpresidente just called into @mikeson. His request to do a joint pizza review was denied. Great radio.', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'stoolpresidente', 'name': 'Dave Portnoy', 'id': 43775786, 'id_str': '43775786', 'indices': [1, 17]}, {'screen_name': 'mikeson', 'name': "MIKE'S ON with Francesa", 'id': 989967822154620929, 'id_str': '989967822154620929', 'indices': [35, 43]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1548776257, 'id_str': '1548776257', 'name': 'Emmanuel Berbari', 'screen_name': 'BerbariOnAir', 'location': 'Fordham University', 'description': '@Yankees Beat Reporter & PxP @WFUVSports | @FordhamRams & ESPN3 | @WFAN660 Freelance | @Westwood1Sports Intern | @BronxNetTV Host |', 'url': 'https://t.co/h6zkj9GCUY', 'entities': {'url': {'urls': [{'url': 'https://t.co/h6zkj9GCUY', 'expanded_url': 'http://emmanuel-berbari.com', 'display_url': 'emmanuel-berbari.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1412, 'friends_count': 817, 'listed_count': 18, 'created_at': 'Wed Jun 26 17:56:32 +0000 2013', 'favourites_count': 17257, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 9505, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1120359454728491010/jyxOrIpm_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1120359454728491010/jyxOrIpm_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1548776257/1555808274', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': {'id': '9530ea3d29844638', 'url': 'https://api.twitter.com/1.1/geo/id/9530ea3d29844638.json', 'place_type': 'city', 'name': 'East Northport', 'full_name': 'East Northport, NY', 'country_code': 'US', 'country': 'United States', 'contained_within': [], 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-73.35523, 40.862419], [-73.286426, 40.862419], [-73.286426, 40.900011], [-73.35523, 40.900011]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 1, 'favorited': False, 'retweeted': False, 'lang': 'en'}
# {'created_at': 'Mon Apr 22 20:36:40 +0000 2019', 'id': 1120426213691023361, 'id_str': '1120426213691023361', 'text': '@FrHarrison @pierogiplease @FrNickOFMConv Fake news, there’s no pierogi on that pizza', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'FrHarrison', 'name': 'Fr. Harrison Ayre 👌🏻', 'id': 410286397, 'id_str': '410286397', 'indices': [0, 11]}, {'screen_name': 'pierogiplease', 'name': '#ᴘɪᴇʀᴏɢɪᴛᴡɪᴛᴛᴇʀ', 'id': 999005935401127936, 'id_str': '999005935401127936', 'indices': [12, 26]}, {'screen_name': 'FrNickOFMConv', 'name': 'Friar Nick, OFM Conv.', 'id': 1636030932, 'id_str': '1636030932', 'indices': [27, 41]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1120423213140459522, 'in_reply_to_status_id_str': '1120423213140459522', 'in_reply_to_user_id': 410286397, 'in_reply_to_user_id_str': '410286397', 'in_reply_to_screen_name': 'FrHarrison', 'user': {'id': 1403120892, 'id_str': '1403120892', 'name': 'Fr. Dan Folwaczny', 'screen_name': 'frrocketdan', 'location': 'Northbrook, IL', 'description': 'Priest of the Archdiocese of Chicago. Rocket scientist. Associate pastor of St. Norbert & OLB. begome saint. No Sin Gang.', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 8983, 'friends_count': 287, 'listed_count': 97, 'created_at': 'Sat May 04 19:00:13 +0000 2013', 'favourites_count': 38602, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 16447, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1110193889619730436/K92Jgnr1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1110193889619730436/K92Jgnr1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1403120892/1550635577', 'profile_link_color': '990000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}

# %%
r = api.request('statuses/filter', {'locations':'-158.24,19.05,-154.89,21.71'})
for item in r:
        print(item)
# Out:
# {'created_at': 'Mon Apr 22 21:14:15 +0000 2019', 'id': 1120435673746550784, 'id_str': '1120435673746550784', 'text': 'Weezy f baby please suck the balls', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3251440891, 'id_str': '3251440891', 'name': '¿', 'screen_name': 'jta__93', 'location': 'Hilo, HI', 'url': None, 'description': 'trouble in paradise', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 259, 'friends_count': 2305, 'listed_count': 12, 'favourites_count': 11726, 'statuses_count': 4631, 'created_at': 'Sun Jun 21 07:48:59 +0000 2015', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1100161274804023296/H0cKyxsY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1100161274804023296/H0cKyxsY_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3251440891/1544288866', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': '7cdc9f8fdbadec68', 'url': 'https://api.twitter.com/1.1/geo/id/7cdc9f8fdbadec68.json', 'place_type': 'city', 'name': 'Wainaku', 'full_name': 'Wainaku, HI', 'country_code': 'US', 'country': 'United States', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-155.115129, 19.734346], [-155.115129, 19.756157], [-155.089421, 19.756157], [-155.089421, 19.734346]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1555967655966'}
# {'created_at': 'Mon Apr 22 21:14:17 +0000 2019', 'id': 1120435681506070528, 'id_str': '1120435681506070528', 'text': 'I just finished walking 1.97 miles in 45m:38s with #Endomondo #endorphins null', 'source': '<a href="https://www.endomondo.com" rel="nofollow">Endomondo</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id':
 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 305, 'friends_count': 79, 'listed_count': 1, 'favourites_count': 1961, 'statuses_count': 3155, 'created_at': 'Sat Sep 03 01:06:20 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'B2DFDA', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif', 'profile_background_tile': False, 'profile_link_color': '93A644', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1115495747330301952/MWDO_kkc_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1115495747330301952/MWDO_kkc_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/366895710/1554789887', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': '9dafd05b1158873b', 'url': 'https://api.twitter.com/1.1/geo/id/9dafd05b1158873b.json', 'place_type': 'admin', 'name': 'Hawaii', 'full_name': 'Hawaii, USA', 'country_code': 'US', 'country': 'Estados Unidos', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-178.443593, 18.86546], [-178.443593, 28.517269], [-154.755792, 28.517269], [-154.755792, 18.86546]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Los caballos y los delfines siempre han sido mis animales favoritos y soy la más feliz del mundo en Hawái por qué te visto delfines todos los días, son hermosos 😍', 'display_text_range': [0, 162], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/AMG1Kfuvnh', 'expanded_url': 'https://twitter.com/i/web/status/1120435703907852288', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'es', 'timestamp_ms': '1555967663157'}
# {'created_at': 'Mon Apr 22 21:14:28 +0000 2019', 'id': 1120435728180219904, 'id_str': '1120435728180219904', 'text': '@Bill_Maxwell_ What a douche bag!', 'display_text_range': [15, 33], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': 1120393110285111296, 'in_reply_to_status_id_str': '1120393110285111296', 'in_reply_to_user_id': 958555581198954497, 'in_reply_to_user_id_str': '958555581198954497', 'in_reply_to_screen_name': 'Bill_Maxwell_', 'user': {'id': 217993152, 'id_str': '217993152', 'name': 'Jan Lyons', 'screen_name': 'janners808', 'location': 'Hawaii', 'url': None, 'description': 'Born and raised on the island of Oahu in the state of Hawaii. #BoycottFoxNews #Resist #tRump #NotMyPresident #LiarInChief🌊🌊🏄\u200d♀️🌊🌊', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 864, 'friends_count': 843, 'listed_count': 0, 'favourites_count': 9576, 'statuses_count': 5569, 'created_at': 'Sun Nov 21 03:28:20 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/975840381093871616/ktJT00Bg_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/975840381093871616/ktJT00Bg_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': 'c47c0bc571bf5427', 'url': 'https://api.twitter.com/1.1/geo/id/c47c0bc571bf5427.json', 'place_type': 'city', 'name': 'Honolulu', 'full_name': 'Honolulu, HI', 'country_code': 'US', 'country': 'United States', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-157.950476, 21.254837], [-157.950476, 21.38505], [-157.648702, 21.38505], [-157.648702, 21.254837]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'Bill_Maxwell_', 'name': '🌊Bill Maxwell 🌊#ImpeachPutin🌊', 'id': 958555581198954497, 'id_str': '958555581198954497', 'indices': [0, 14]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1555967668944'}
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-597ec751deee> in <module>
#       1 r = api.request('statuses/filter', {'locations':'-158.24,19.05,-154.89,21.71'})
# ----> 2 for item in r:
#       3         print(item)
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in __iter__(self)
#     330         :raises: TwitterConnectionError
#     331         """
# --> 332         for item in self._iter_stream():
#     333             if item:
#     334                 try:
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in _iter_stream(self)
#     299                 while True:
#     300                     # read bytes until item boundary reached
# --> 301                     buf += self.stream.read(1)
#     302                     if not buf:
#     303                         # check for stall (i.e. no data for 90 seconds)
#
# /anaconda3/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# /anaconda3/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /anaconda3/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# /anaconda3/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# /anaconda3/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# /anaconda3/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-41-52b7ec8d97cc> in <module>
# ----> 1 r.json()
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in json(self, **kwargs)
#     195         :raises: ValueError
#     196         """
# --> 197         return self.response.json(**kwargs)
#     198
#     199     def get_iterator(self):
#
# /anaconda3/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# res = api.request('tweets/search/%s/:%s' % (sandbox, label),
#                   {'query':'point_radius:[-155.5149 19.6242 50mi]', # Long/Lat for Hawaii (big island)
#                    'toDate':'201904010000', # start date = 04/01/2019
#                    'fromDate':'201904150000', # end date = 04/15/2019
#                    'next': next
# })

# while next is not None:
res = api.request('https://stream.twitter.com/1.1/statuses/filter.json',{
    #'query':'bounding_box:[-158.24,19.05,-154.89,21.71]' # Long/Lat for Hawaii
    #'toDate':'201904010000', # start date = 04/01/2019
    #'fromDate':'201904150000', # end date = 04/15/2019
    #'next': next
})

print('res.status_code: ', res.status_code)
#     next = res.json()['next']
#     print('next: ', next)
#     print('web_request_count: ', web_request_count)
#     web_request_count += 1

#     results = res.json()['results']

#     for tweet in results:

#         coordinates = tweet['coordinates']['coordinates']
#         tweet_date = tweet['created_at']
#         tweet_text = tweet['text']                              

#         if 'extended_tweet' in tweet.keys():
#             tweet_text = tweet['extended_tweet']['full_text']  

#         tweet_row = {'long_lat':coordinates,
#                     'date_utc':tweet_date,
#                     'full_text':tweet_text}

#         list_tweets.append(tweet_row) 

#     df = pd.DataFrame(list_tweets)

#     df.to_json('tweets_hawaii_2019_april_1-15.json', orient='records')
    
#     time.sleep(2) # wait i.e. only 30 requests per minute allowed
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-a9a5de6635c8> in <module>
#       7
#       8 # while next is not None:
# ----> 9 res = api.request('https://stream.twitter.com/1.1/statuses/filter.json',{
#      10     #'query':'bounding_box:[-158.24,19.05,-154.89,21.71]' # Long/Lat for Hawaii
#      11     #'toDate':'201904010000', # start date = 04/01/2019
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in request(self, resource, params, files, method_override)
#     120         :raises: TwitterConnectionError
#     121         """
# --> 122         resource, endpoint = self._get_endpoint(resource)
#     123         if endpoint not in ENDPOINTS:
#     124             raise Exception('Endpoint "%s" unsupported' % endpoint)
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in _get_endpoint(self, resource)
#     102             parts = resource.split('/')
#     103             # embedded parameters start with ':'
# --> 104             parts = [k if k[0] != ':' else ':PARAM' for k in parts]
#     105             endpoint = '/'.join(parts)
#     106             resource = resource.replace(':', '')
#
# /anaconda3/lib/python3.6/site-packages/TwitterAPI/TwitterAPI.py in <listcomp>(.0)
#     102             parts = resource.split('/')
#     103             # embedded parameters start with ':'
# --> 104             parts = [k if k[0] != ':' else ':PARAM' for k in parts]
#     105             endpoint = '/'.join(parts)
#     106             resource = resource.replace(':', '')
#
# IndexError: string index out of range

# %%
results = res.json()['results']
print(len(results))
print(len(list_tweets))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-253a174cc84b> in <module>
# ----> 1 results = res.json()['results']
#       2 print(len(results))
#       3 print(len(list_tweets))
#
# KeyError: 'results'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
