# %%
import pandas as pd
import json
import time

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search"

querystring = {"location":"honolulu"}

payload = ""
headers = {
    'Authorization': "Bearer xrguIU46sh43dDFWgw4uG4ONduJ41dSD1t_fPI7RJadMn8F-GlOOYVK3UbY0etZ78uwgX5FrtWLNpslpa0zXCYyQ5ItE6skRo3BARG2j6U484D_Xl8PURkWjB4-4XHYx",
    'cache-control': "no-cache",
    'Postman-Token': "6a35505d-0a28-433b-ae01-433449c564a5"
    }

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# {"businesses": [{"id": "o3edBEVjRcYJnQWrSFd9Bg", "alias": "marukame-udon-honolulu", "name": "Marukame Udon", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/iTBFTGVIB9nV9tg1LeK9AQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/marukame-udon-honolulu?adjust_creative=kal4NBJ4OrvzJwXvJJ5c9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kal4NBJ4OrvzJwXvJJ5c9A", "review_count": 8554, "categories": [{"alias": "japanese", "title": "Japanese"}, {"alias": "noodles", "title": "Noodles"}], "rating": 4.5, "coordinates": {"latitude": 21.2795065887446, "longitude": -157.825928889584}, "transactions": [], "price": "$", "location": {"address1": "2310 Kuhio Ave", "address2": "Ste 124", "address3": "", "city": "Honolulu", "zip_code": "96815", "country": "US", "state": "HI", "display_address": ["2310 Kuhio Ave", "Ste 124", "Honolulu, HI 96815"]}, "phone": "+18089316000", "display_phone": "(808) 931-6000", "distance": 4173.53922889884}, {"id": "7bJ83Jb_DTAF0eO
# ...

# %%
businesses = response.json()

# %%
businesses['businesses']
# Out:
# [{'id': 'o3edBEVjRcYJnQWrSFd9Bg',
#   'alias': 'marukame-udon-honolulu',
#   'name': 'Marukame Udon',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/iTBFTGVIB9nV9tg1LeK9AQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/marukame-udon-honolulu?adjust_creative=kal4NBJ4OrvzJwXvJJ5c9A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=kal4NBJ4OrvzJwXvJJ5c9A',
#   'review_count': 8554,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.2795065887446,
#    'longitude': -157.825928889584},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2310 Kuhio Ave',
#    'address2': 'Ste 124',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2310 Kuhio Ave', 'Ste 124', 'Honolulu, HI 96815']},
#   'phone': '+18089316000',
# ...

# %%
pd.DataFrame(businesses['businesses'])
# Out:
#                                          alias  \
# 0                       marukame-udon-honolulu
# 1                     leonards-bakery-honolulu
# 2                         ono-seafood-honolulu
# 3                 musubi-cafe-iyasume-honolulu
# 4               helenas-hawaiian-food-honolulu
# 5                     liliha-bakery-honolulu-2
# 6   uncle-clays-house-of-pure-aloha-honolulu-2
# 7                    waiola-shave-ice-honolulu
# 8                     dukes-waikiki-honolulu-2
# 9                        roys-waikiki-honolulu
# 10             gen-korean-bbq-house-honolulu-4
# 11                alan-wongs-honolulu-honolulu
# 12        diamond-head-state-monument-honolulu
# 13              tonkatsu-ginza-bairin-honolulu
# 14                        lucky-belly-honolulu
# 15                  sweet-home-cafe-honolulu-3
# 16                    sweet-es-cafe-honolulu-4
# 17                    nicos-pier-38-honolulu-2
# 18                tikis-grill-and-bar-honolulu
# ...

# %%
hawaii_cities = ['ocean_view_hawaii', 'pāhoa_hawaii', 'honokaa_hawaii',
                 'hawi_hawaii', 'waemia_hawaii', 'waikoloa_village_hawaii',
                 'kailua_hawaii', 'captain_cook_hawaii']

url = "https://api.yelp.com/v3/businesses/search"
payload = ""
headers = {
    'Authorization': "Bearer xrguIU46sh43dDFWgw4uG4ONduJ41dSD1t_fPI7RJadMn8F-GlOOYVK3UbY0etZ78uwgX5FrtWLNpslpa0zXCYyQ5ItE6skRo3BARG2j6U484D_Xl8PURkWjB4-4XHYx",
    'cache-control': "no-cache",
    'Postman-Token': "6a35505d-0a28-433b-ae01-433449c564a5"
    }

hawaii_businesses = []
offset = 0


for city in hawaii_cities:
    print(f'City: {city.upper()}')
    offset = 0
    for i in range(20):
        print(f'Page number: {i}')
        params = {"location": city, "limit":50, "offset": offset}
        offset = offset + 50
        url = url
        req = requests.request("GET", url, data=payload, headers=headers, params=params)
        if req.status_code != 200: 
            print(json.loads(req.text))
            print(each)
            break
        else:
            parsed = json.loads(req.text)
            hawaii_businesses.extend(parsed['businesses'])
            print(f'Number of businesses parsed: {len(hawaii_businesses)}')
            time.sleep(1)
# Out:
# City: OCEAN_VIEW_HAWAII
# Page number: 0
# Number of businesses parsed: 12
# Page number: 1
# Number of businesses parsed: 12
# Page number: 2
# Number of businesses parsed: 12
# Page number: 3
# Number of businesses parsed: 12
# Page number: 4
# Number of businesses parsed: 12
# Page number: 5
# Number of businesses parsed: 12
# Page number: 6
# Number of businesses parsed: 12
# Page number: 7
# Number of businesses parsed: 12
# Page number: 8
# Number of businesses parsed: 12
# Page number: 9
# Number of businesses parsed: 12
# Page number: 10
# Number of businesses parsed: 12
# Page number: 11
# Number of businesses parsed: 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-93b4a4714cf7> in <module>
#      32             hawaii_businesses.extend(parsed['businesses'])
#      33             print(f'Number of businesses parsed: {len(hawaii_businesses)}')
# ...

# %%
pd.DataFrame(businesses).iloc[999,:]
# Out:
# alias                                     tr-fire-grill-honolulu-3
# categories       [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# coordinates      {'latitude': 21.2786350248632, 'longitude': -1...
# display_phone                                       (808) 921-2330
# distance                                                   4307.26
# id                                          4IDYlNSh2Z3jMG7GhN_hMA
# image_url        https://s3-media2.fl.yelpcdn.com/bphoto/uci-_e...
# is_closed                                                    False
# location         {'address1': '2330 Kuhio Ave', 'address2': '',...
# name                                                 TR Fire Grill
# phone                                                 +18089212330
# price                                                           $$
# rating                                                         3.5
# review_count                                                   209
# ...
